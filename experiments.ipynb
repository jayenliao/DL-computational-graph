# %% [markdown]
# # Deep Learning - Assignment 2
#
# This is the python notebook with experiments for assignment 2 of Deep Learning, a course at Institute of Data Science, National Cheng Kung University.
#
# - Author: Jay C. Liao
# - ID: RE6094028
# - Email: re6094028@gs.ncku.edu.tw

# %%
import importlib
import args
import main
import exp_hidden_act
import source.trainers
import source.models
import source.layers
importlib.reload(args)
importlib.reload(main)
importlib.reload(exp_hidden_act)
importlib.reload(source.trainers)
importlib.reload(source.models)
importlib.reload(source.layers)
# Out:
# <module 'source.layers' from '/home/jayliao2/DL_2021/hw2/source/layers.py'>

# %% [markdown]
# ## One-layer perceptron

# %%
# %run main.py --models 'OneLayerPerceptron' --epochs 500 --savePATH './output/_OneLayerPerceptron'
# Out:
#  30%|███       | 75/247 [00:00<00:00, 739.74it/s]
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: OneLayerPerceptron
# lr = 0.01|  Optimizer: Adam | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 500)
# ...
#  26%|██▌       | 63/247 [00:00<00:00, 625.49it/s]
# Epoch   30
# Training loss=3.7160
#   Training accuracy: 0.0746 (top-1) 0.2544 (top-5)
# Validation accuracy: 0.0711 (top-1) 0.2689 (top-5)
# ...
#  26%|██▌       | 63/247 [00:00<00:00, 626.47it/s]
# Epoch   60
# Training loss=3.6905
#   Training accuracy: 0.0786 (top-1) 0.2653 (top-5)
# Validation accuracy: 0.0622 (top-1) 0.2822 (top-5)
# ...
#  25%|██▍       | 61/247 [00:00<00:00, 607.69it/s]
# Epoch   90
# Training loss=3.6468
# ...

# %% [markdown]
# ## Two-layer perceptron

# %%
# %run main.py --models 'TwoLayerPerceptron' --epochs 500 --savePATH './output/_TwoLayerPerceptron'
# Out:
#  25%|██▍       | 61/247 [00:00<00:00, 606.53it/s]
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerPerceptron
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Act. fun. of the hidden layer: None | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 500)
# ...
#  21%|██▏       | 53/247 [00:00<00:00, 520.87it/s]
# Epoch   30
# Training loss=3.7139
#   Training accuracy: 0.0813 (top-1) 0.2754 (top-5)
# Validation accuracy: 0.0689 (top-1) 0.2911 (top-5)
# ...
#  22%|██▏       | 54/247 [00:00<00:00, 532.00it/s]
# Epoch   60
# Training loss=3.6469
#   Training accuracy: 0.0823 (top-1) 0.2787 (top-5)
# Validation accuracy: 0.0711 (top-1) 0.2956 (top-5)
# ...
#  21%|██        | 52/247 [00:00<00:00, 517.80it/s]
# ...

# %%
# %run main.py --models 'TwoLayerPerceptron' --epochs 500 --savePATH './output/_TwoLayerPerceptron' --feature_types 'SURF'
# Out:
#   0%|          | 0/247 [00:00<?, ?it/s]
# ======= Feature type: SURF =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 64) (450, 64) (450, 64)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerPerceptron
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Act. fun. of the hidden layer: None | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 500)
# ...
#  20%|██        | 50/247 [00:00<00:00, 494.94it/s]
# Epoch   30
# Training loss=3.5160
#   Training accuracy: 0.0909 (top-1) 0.2998 (top-5)
# Validation accuracy: 0.0733 (top-1) 0.2711 (top-5)
# ...
#  20%|█▉        | 49/247 [00:00<00:00, 489.98it/s]
# Epoch   60
# Training loss=3.7138
#   Training accuracy: 0.1038 (top-1) 0.3296 (top-5)
# Validation accuracy: 0.1022 (top-1) 0.3000 (top-5)
# ...
#  20%|█▉        | 49/247 [00:00<00:00, 484.11it/s]
# Epoch   90
# ...

# %% [markdown]
# ## Two-Layer Network (the hidden state is activated)

# %%
# %run main.py --models 'TwoLayerNet' --epochs 500 --savePATH './output/_TwoLayerNet'
# Out:
#  22%|██▏       | 54/247 [00:00<00:00, 533.83it/s]
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Act. fun. of the hidden layer: ReLU | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 500)
# ...
#  20%|█▉        | 49/247 [00:00<00:00, 484.43it/s]
# Epoch   30
# Training loss=3.6403
#   Training accuracy: 0.0909 (top-1) 0.2985 (top-5)
# Validation accuracy: 0.1067 (top-1) 0.2822 (top-5)
# ...
#  20%|█▉        | 49/247 [00:00<00:00, 483.55it/s]
# Epoch   60
# Training loss=3.5369
#   Training accuracy: 0.0969 (top-1) 0.3171 (top-5)
# Validation accuracy: 0.0933 (top-1) 0.3111 (top-5)
# ...
#  11%|█         | 26/247 [00:00<00:00, 258.52it/s]
# Epoch   90
# ...

# %% [markdown]
# ## Experiment of Different Activation Functions of The Hidden Layer

# %%
# %run main.py --model 'TwoLayerNet' --hidden_layer_act 'tanh' --savePATH './output/exp_hidden_act' --feature_types 'SURF' --epochs 100 --print_result_per_epochs 10
# Out:
#  17%|█▋        | 43/247 [00:00<00:00, 425.73it/s]
# ======= Feature type: SURF =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 64) (450, 64) (450, 64)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Act. fun. of the hidden layer: tanh | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 100)
# ...
#  16%|█▌        | 40/247 [00:00<00:00, 394.55it/s]
# Epoch   10
# Training loss=3.7375
#   Training accuracy: 0.0685 (top-1) 0.2516 (top-5)
# Validation accuracy: 0.0533 (top-1) 0.2333 (top-5)
# ...
#  15%|█▍        | 37/247 [00:00<00:00, 369.49it/s]
# Epoch   20
# Training loss=3.6344
#   Training accuracy: 0.0862 (top-1) 0.2870 (top-5)
# Validation accuracy: 0.0600 (top-1) 0.2644 (top-5)
# ...
#  16%|█▌        | 40/247 [00:00<00:00, 390.43it/s]
# Epoch   30
# ...

# %%
# %run exp_hidden_act.py --savePATH './output/exp_hidden_act' --feature_types 'Histogram' --epochs 500 --print_result_per_epochs 100
# Out:
#  22%|██▏       | 54/247 [00:00<00:00, 537.98it/s]
# ----> Activation function of the hidden layer = ReLU
#
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Act. fun. of the hidden layer: ReLU | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 500)
# ...
#  19%|█▉        | 47/247 [00:00<00:00, 469.66it/s]
# Epoch  100
# Training loss=3.4181
#   Training accuracy: 0.1014 (top-1) 0.3269 (top-5)
# Validation accuracy: 0.0956 (top-1) 0.3200 (top-5)
# ...
#  19%|█▊        | 46/247 [00:00<00:00, 458.38it/s]
# Epoch  200
# Training loss=3.4633
#   Training accuracy: 0.1046 (top-1) 0.3356 (top-5)
# Validation accuracy: 0.1111 (top-1) 0.3467 (top-5)
# ...

# %%
# %run exp_hidden_act.py --savePATH './output/exp_hidden_act' --feature_types 'Histogram' --epochs 500 --print_result_per_epochs 100
# Out:
#  21%|██▏       | 53/247 [00:00<00:00, 527.98it/s]
# ----> Activation function of the hidden layer = ReLU
#
# ======= Feature type: Histogram =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 15) (450, 15) (450, 15)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Act. fun. of the hidden layer: ReLU | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 500)
# ...
#  17%|█▋        | 43/247 [00:00<00:00, 420.51it/s]
# Epoch  100
# Training loss=3.4256
#   Training accuracy: 0.0983 (top-1) 0.3225 (top-5)
# Validation accuracy: 0.1111 (top-1) 0.3089 (top-5)
# ...
#  18%|█▊        | 45/247 [00:00<00:00, 447.99it/s]
# Epoch  200
# Training loss=3.4166
#   Training accuracy: 0.1026 (top-1) 0.3320 (top-5)
# Validation accuracy: 0.1022 (top-1) 0.3378 (top-5)
# ...

# %%
# %run exp_hidden_act.py --verbose --savePATH './output/exp_hidden_act' --feature_types 'SIFT' --epochs 500 --print_result_per_epochs 100
# Out:
# ----> Activation function of the hidden layer = ReLU
#
# ======= Feature type: SIFT =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 128) (450, 128) (450, 128)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Act. fun. of the hidden layer: ReLU | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 500)
# Epoch  200
# Training loss=3.1417
#   Training accuracy: 0.1402 (top-1) 0.4070 (top-5)
# Validation accuracy: 0.1356 (top-1) 0.3822 (top-5)
# Epoch  300
# Training loss=3.2021
#   Training accuracy: 0.1397 (top-1) 0.4027 (top-5)
# Validation accuracy: 0.1400 (top-1) 0.3778 (top-5)
# Epoch  400
# Training loss=3.3402
#   Training accuracy: 0.1341 (top-1) 0.3938 (top-5)
# Validation accuracy: 0.1156 (top-1) 0.3800 (top-5)
# Epoch  500
# ...

# %%
# %run exp_hidden_act.py --verbose --savePATH './output/exp_hidden_act' --feature_types 'SURF' --epochs 500 --print_result_per_epochs 100
# Out:
# ----> Activation function of the hidden layer = ReLU
#
# ======= Feature type: SURF =======
# Loading preprocessed datasets ...
#
# Shapes of feature matrices (Train | Val | Test):  (63325, 64) (450, 64) (450, 64)
# Shapes of y label matrices (Train | Val | Test):  (63325, 50) (450, 50) (450, 50)
#
# ---> Model: TwoLayerNet
# lr = 0.01|  Optimizer: Adam | Hidden size: 32 | Act. fun. of the hidden layer: ReLU | Act. fun. of the output layer: SoftmaxWithCrossEntropyLoss |
#
# Training a new model ...  (Batch size = 256, No. of epochs = 500)
# Epoch  100
# Training loss=3.3584
#   Training accuracy: 0.1000 (top-1) 0.3211 (top-5)
# Validation accuracy: 0.0711 (top-1) 0.3022 (top-5)
# Epoch  200
# Training loss=3.3279
#   Training accuracy: 0.1145 (top-1) 0.3474 (top-5)
# Validation accuracy: 0.0956 (top-1) 0.3156 (top-5)
# Epoch  300
# Training loss=3.4537
#   Training accuracy: 0.1213 (top-1) 0.3581 (top-5)
# Validation accuracy: 0.0956 (top-1) 0.3089 (top-5)
# Epoch  400
# ...
